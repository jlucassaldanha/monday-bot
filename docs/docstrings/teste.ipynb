# %% [markdown]
# Starts a commercial on the specified channel.
#
# **NOTE**: Only partners and affiliates may run commercials and they must be streaming live at the time.
#
# **NOTE**: Only the broadcaster may start a commercial; the broadcaster’s editors and moderators may not start commercials on behalf of the broadcaster.
#
# ### Authorization
#
# Requires a [user access token](/docs/authentication#user-access-tokens) that includes the **channel:edit:commercial** scope.
#
# ### URL
#
# `POST https://api.twitch.tv/helix/channels/commercial`

# %% [markdown]
# | Field | Type | Description |
# | --- | --- | --- |
# | broadcaster\_id | String | The ID of the partner or affiliate broadcaster that wants to run the commercial. This ID must match the user ID found in the OAuth token. |
# | length | Integer | The length of the commercial to run, in seconds. Twitch tries to serve a commercial that’s the requested length, but it may be shorter or longer. The maximum length you should request is 180 seconds. |

# %%
class teste():
    def __init__(self):
        r"""
        Starts a commercial on the specified channel.

        **NOTE**: Only partners and affiliates may run commercials and they must be streaming live at the time.

        **NOTE**: Only the broadcaster may start a commercial; the broadcaster’s editors and moderators may not start commercials on behalf of the broadcaster.

        ### Authorization

        Requires a [user access token](/docs/authentication#user-access-tokens) that includes the **channel:edit:commercial** scope.

        ### URL

        `POST https://api.twitch.tv/helix/channels/commercial`

        | Field | Type | Description |
| --- | --- | --- |
| broadcaster_id | String | The ID of the partner or affiliate broadcaster that wants to run the commercial. This ID must match the user ID found in the OAuth token. |
| length | Integer | The length of the commercial to run, in seconds. Twitch tries to serve a commercial that’s the requested length, but it may be shorter or longer. The maximum length you should request is 180 seconds. |
        """
        pass

# %%
teste()

# %% [markdown]
# get-ad-schedule
# snooze-next-ad
# get-extension-analytics
# get-game-analytics
# get-bits-leaderboard
# get-cheermotes
# get-extension-transactions
# get-channel-information
# get-channel-editors
# get-followed-channels
# get-channel-followers
# delete-custom-reward
# get-custom-reward
# get-custom-reward-redemption
# get-charity-campaign
# get-charity-campaign-donations
# get-chatters
# get-channel-emotes
# get-global-emotes
# get-emote-sets
# get-channel-chat-badges
# get-global-chat-badges
# get-chat-settings
# get-shared-chat-session
# get-user-emotes
# send-a-shoutout
# get-user-chat-color
# update-user-chat-color
# create-clip
# get-clips
# get-conduits
# delete-conduit
# get-conduit-shards
# get-content-classification-labels
# get-drops-entitlements
# get-extension-configuration-segment
# get-extension-live-channels
# get-extension-secrets
# create-extension-secret
# get-extensions
# get-released-extensions
# get-extension-bits-products
# update-extension-bits-product
# delete-eventsub-subscription
# get-eventsub-subscriptions
# get-top-games
# get-games
# get-creator-goals
# get-channel-guest-star-settings
# get-guest-star-session
# create-guest-star-session
# end-guest-star-session
# get-guest-star-invites
# send-guest-star-invite
# delete-guest-star-invite
# assign-guest-star-slot
# update-guest-star-slot
# delete-guest-star-slot
# update-guest-star-slot-settings
# get-hype-train-events
# get-automod-settings
# get-banned-users
# unban-user
# get-unban-requests
# resolve-unban-requests
# get-blocked-terms
# remove-blocked-term
# delete-chat-messages
# get-moderated-channels
# get-moderators
# add-channel-moderator
# remove-channel-moderator
# get-vips
# add-channel-vip
# remove-channel-vip
# get-shield-mode-status
# get-polls
# get-predictions
# start-a-raid
# cancel-a-raid
# get-channel-stream-schedule
# get-channel-icalendar
# update-channel-stream-schedule
# delete-channel-stream-schedule-segment
# search-categories
# search-channels
# get-stream-key
# get-streams
# get-followed-streams
# get-stream-markers
# get-broadcaster-subscriptions
# check-user-subscription
# get-all-stream-tags
# get-stream-tags
# get-channel-teams
# get-teams
# get-users
# update-user
# get-user-block-list
# block-user
# unblock-user
# get-user-extensions
# get-user-active-extensions
# get-videos
# delete-videos
# send-whisper
# PS C:\Users\jluca\Documents\python\my-twitch-bot> ^C
# PS C:\Users\jluca\Documents\python\my-twitch-bot>
# PS C:\Users\jluca\Documents\python\my-twitch-bot>  c:; cd 'c:\Users\jluca\Documents\python\my-twitch-bot'; & 'c:\Users\jluca\AppData\Local\Programs\Python\Python312\python.exe' 'c:\Users\jluca\.vscode\extensions\ms-python.debugpy-2025.6.0-win32-x64\bundled\libs\debugpy\launcher' '53201' '--' 'C:\Users\jluca\Documents\python\my-twitch-bot\docs\errors docs\gethtmlinfo.py'
# get-ad-schedule
# snooze-next-ad
# get-extension-analytics
# get-game-analytics
# get-bits-leaderboard
# get-cheermotes
# get-extension-transactions
# get-channel-information
# get-channel-editors
# get-followed-channels
# get-channel-followers
# delete-custom-reward
# get-custom-reward
# get-custom-reward-redemption
# get-charity-campaign
# get-charity-campaign-donations
# get-chatters
# get-channel-emotes
# get-global-emotes
# get-emote-sets
# get-channel-chat-badges
# get-global-chat-badges
# get-chat-settings
# get-shared-chat-session
# get-user-emotes
# send-a-shoutout
# get-user-chat-color
# update-user-chat-color
# create-clip
# get-clips
# get-conduits
# delete-conduit
# get-conduit-shards
# get-content-classification-labels
# get-drops-entitlements
# get-extension-configuration-segment
# get-extension-live-channels
# get-extension-secrets
# create-extension-secret
# get-extensions
# get-released-extensions
# get-extension-bits-products
# update-extension-bits-product
# delete-eventsub-subscription
# get-eventsub-subscriptions
# get-top-games
# get-games
# get-creator-goals
# get-channel-guest-star-settings
# get-guest-star-session
# create-guest-star-session
# end-guest-star-session
# get-guest-star-invites
# send-guest-star-invite
# delete-guest-star-invite
# assign-guest-star-slot
# update-guest-star-slot
# delete-guest-star-slot
# update-guest-star-slot-settings
# get-hype-train-events
# get-automod-settings
# get-banned-users
# unban-user
# get-unban-requests
# resolve-unban-requests
# get-blocked-terms
# remove-blocked-term
# delete-chat-messages
# get-moderated-channels
# get-moderators
# add-channel-moderator
# remove-channel-moderator
# get-vips
# add-channel-vip
# remove-channel-vip
# get-shield-mode-status
# get-polls
# get-predictions
# start-a-raid
# cancel-a-raid
# get-channel-stream-schedule
# get-channel-icalendar
# update-channel-stream-schedule
# delete-channel-stream-schedule-segment
# search-categories
# search-channels
# get-stream-key
# get-streams
# get-followed-streams
# get-stream-markers
# get-broadcaster-subscriptions
# check-user-subscription
# get-all-stream-tags
# get-stream-tags
# get-channel-teams
# get-teams
# get-users
# update-user
# get-user-block-list
# block-user
# unblock-user
# get-user-extensions
# get-user-active-extensions
# get-videos
# delete-videos
# send-whisper
